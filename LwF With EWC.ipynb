# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchvision.datasets as dsets
from torch.autograd import Variable
import numpy as np
from torch.utils.data import DataLoader
import torchvision

# %%
def seed_everything(seed: int = 42):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(0)

# %%
print('STEP 1: LOADING DATASET')

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

train_dataset = dsets.CIFAR10(
    root='./data/CIFAR10/',
    train=True,
    transform=transform_train,
    download=True
)

test_dataset = dsets.CIFAR10(
    root='./data/CIFAR10/',
    train=False,
    transform=transform_test
)
# Out:
# STEP 1: LOADING DATASET
# Files already downloaded and verified

# %%
def remove_samples(dataset, l=[]):
    targets = []
    data = []
    for d, t in zip(dataset.data, dataset.targets):
        if t in l:
            continue
        else:
            targets.append(t)
            data.append(d)
    dataset.targets = targets
    dataset.data = data
    return dataset

train_dataset = remove_samples(train_dataset, [5,6,7,8,9])

# %%
print('STEP 2: MAKING DATASET ITERABLE')
train_loader = torch.utils.data.DataLoader(
    dataset=train_dataset,
    batch_size=128,
    shuffle=True,
    num_workers=4
)

test_loader = torch.utils.data.DataLoader(
    dataset=test_dataset,
    batch_size=100,
    shuffle=False,
    num_workers=4,
)
# Out:
# STEP 2: MAKING DATASET ITERABLE

# %%
print('STEP 3: CREATE MODEL CLASS')
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10, temp=1.0):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.fc = nn.Linear(512 * block.expansion, num_classes)
        self.temp = temp

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.fc(out) / self.temp  
        return out


def resnet18(temp=1.0, **kwargs):
    model = ResNet(BasicBlock, [2, 2, 2, 2], temp=temp, **kwargs)
    return model
# Out:
# STEP 3: CREATE MODEL CLASS

# %%
print('STEP 4: INSTANTIATE MODEL CLASS')
model = resnet18(num_classes=5)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# STEP 4: INSTANTIATE MODEL CLASS
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (fc): Linear(in_features=512, out_features=5, bias=True)
# )

# %%
print('STEP 5: INSTANTIATE LOSS CLASS')
criterion = nn.CrossEntropyLoss()
# Out:
# STEP 5: INSTANTIATE LOSS CLASS

# %%
print('STEP 6: INSTANTIATE OPTIMIZER CLASS')
num_epochs = 20

learning_rate = 1e-2
momentum = 0.9
weight_decay = 5e-4

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum = momentum, weight_decay = weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)
# Out:
# STEP 6: INSTANTIATE OPTIMIZER CLASS

# %%
# Codes below were commented for simplicity of project(We are using pretrained weights)

# print('STEP 7: TRAIN THE MODEL')
# # Train
# for epoch in range(num_epochs):
#     model.train()
#     loss_avg = 0.
#     for i, (images, labels) in enumerate(train_loader):
#         images = images.to(device)
#         labels = labels.to(device)

#         outputs = model(images)

#         loss = criterion(outputs, labels)
        
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()
        
#         loss_avg += loss.item()
        
#     scheduler.step()
    
#     print(f'Epochs: {epoch}. Loss: {loss_avg / len(train_loader):.5f}.')

# %%
# model.load_state_dict(torch.load('./resnet18_base_weight/resnet18_base.pth'))

# %%
# # Test
# class_name = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# correct = {f"{i}": 0 for i in range(10)}
# total = {f"{i}": 0 for i in range(10)}

# model.eval()
# with torch.no_grad():
#     for images, labels in test_loader:
#         images = images.to(device)
#         outputs = model(images)
#         _, predicted = torch.max(outputs.data, 1)
        
#         for label, prediction in zip(labels, predicted):
#             if label == prediction.cpu():
#                 correct[str(label.item())] += 1
#             total[str(label.item())] += 1
    
#     total_ = 0.
#     correct_ = 0.
#     for idx, correct_count in correct.items():
#         total_ += total[idx]
#         correct_ += correct_count
#     accuracy = 100 * float(correct_) / total_
#     print(f'Total Accuracy: {accuracy:3.1f} %')
    
#     total_ = 0.
#     correct_ = 0.
#     for idx, correct_count in correct.items():
#         if int(idx) in [0,1,2,3,4]:
#             total_ += total[idx]
#             correct_ += correct_count
#     try:
#         accuracy = 100 * float(correct_) / total_
#     except ZeroDivisionError:
#         print(f'Old classes Accuracy: 00.0 %')
#     else:
#         print(f'Old classes Accuracy: {accuracy:3.1f} %')
    
#     total_ = 0.
#     correct_ = 0.
#     for idx, correct_count in correct.items():
#         if int(idx) in [5,6,7,8,9]:
#             total_ += total[idx]
#             correct_ += correct_count
#     try:
#         accuracy = 100 * float(correct_) / total_
#     except ZeroDivisionError:
#         print(f'Novel classes Accuracy: 00.0 %')
#     else:
#         print(f'Novel classes Accuracy: {accuracy:3.1f} %')
    
#     print('Accuracy for class')
#     for idx, correct_count in correct.items():
#         accuracy = 100 * float(correct_count) / total[idx]
#         print(f'\t{class_name[int(idx)]:10s} : {accuracy:3.1f} %')

# %%
# torch.save(model.state_dict(), 'resnet18_base.pth')

# %%
# Create the ResNet model for 10 classes
model = resnet18(num_classes=10)

# Load pre-trained weights for the initial 5 classes
pretrained_weights_path = './resnet18_base_weight/resnet18_base.pth'
pretrained_dict = torch.load(pretrained_weights_path)

# Get the current state dict
model_dict = model.state_dict()

# Filter out the final layer weights from the pre-trained dict
pretrained_dict = {k: v for k, v in pretrained_dict.items() if k in model_dict and 'fc' not in k}

# Update the current model dict with the pre-trained weights
model_dict.update(pretrained_dict)

# Load the updated state dict into the model
model.load_state_dict(model_dict)

# Manually initialize the final layer weights
with torch.no_grad():
    # Get the pre-trained weights for the original 5 classes
    pretrained_fc_weights = torch.load(pretrained_weights_path)['fc.weight']
    pretrained_fc_bias = torch.load(pretrained_weights_path)['fc.bias']

    # Initialize the first 5 weights with pre-trained values
    model.fc.weight[:5] = pretrained_fc_weights
    model.fc.bias[:5] = pretrained_fc_bias

    # Initialize the remaining 5 weights with Xavier initialization
    nn.init.xavier_uniform_(model.fc.weight[5:])
    model.fc.bias[5:].zero_()

# Move the model to the correct device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
old_model = model.to(device)

# Initialize the new model
new_model = resnet18(num_classes=10).to(device)
with torch.no_grad():
    nn.init.xavier_uniform_(new_model.fc.weight[5:])
    new_model.fc.bias[5:].zero_()

# %%
# Test, Checking process for whether weight load is properly done, used only for initialization purposes
# Set to "old_model"

# class_name = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# correct = {f"{i}": 0 for i in range(10)}
# total = {f"{i}": 0 for i in range(10)}

# old_model.eval()
# with torch.no_grad():
#     for images, labels in test_loader:
#         images = images.to(device)
#         outputs = old_model(images)
#         _, predicted = torch.max(outputs.data, 1)
        
#         for label, prediction in zip(labels, predicted):
#             if label == prediction.cpu():
#                 correct[str(label.item())] += 1
#             total[str(label.item())] += 1
    
#     total_ = 0.
#     correct_ = 0.
#     for idx, correct_count in correct.items():
#         total_ += total[idx]
#         correct_ += correct_count
#     accuracy = 100 * float(correct_) / total_
#     print(f'Total Accuracy: {accuracy:3.1f} %')
    
#     total_ = 0.
#     correct_ = 0.
#     for idx, correct_count in correct.items():
#         if int(idx) in [0,1,2,3,4]:
#             total_ += total[idx]
#             correct_ += correct_count
#     try:
#         accuracy = 100 * float(correct_) / total_
#     except ZeroDivisionError:
#         print(f'Old classes Accuracy: 00.0 %')
#     else:
#         print(f'Old classes Accuracy: {accuracy:3.1f} %')
    
#     total_ = 0.
#     correct_ = 0.
#     for idx, correct_count in correct.items():
#         if int(idx) in [5,6,7,8,9]:
#             total_ += total[idx]
#             correct_ += correct_count
#     try:
#         accuracy = 100 * float(correct_) / total_
#     except ZeroDivisionError:
#         print(f'Novel classes Accuracy: 00.0 %')
#     else:
#         print(f'Novel classes Accuracy: {accuracy:3.1f} %')
    
#     print('Accuracy for class')
#     for idx, correct_count in correct.items():
#         accuracy = 100 * float(correct_count) / total[idx]
#         print(f'\t{class_name[int(idx)]:10s} : {accuracy:3.1f} %')

# %%
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

train_dataset = dsets.CIFAR10(
    root='./data/CIFAR10/',
    train=True,
    transform=transform_train,
    download=True
)

# New dataset for 0~4
train_new_dataset = remove_samples(train_dataset, [0,1,2,3,4])

train_new_loader = torch.utils.data.DataLoader(
    dataset=train_new_dataset,
    batch_size=128,
    shuffle=True,
    num_workers=4
)
# Out:
# Files already downloaded and verified

# %%
# Evaluation set as a function, for simplicity in implementing and finding acc for future models

def evaluate_model(model, test_loader, device):
    class_name = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
    correct = {str(i): 0 for i in range(10)}
    total = {str(i): 0 for i in range(10)}
    
    model.eval()
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            
            for label, prediction in zip(labels, predicted):
                if label == prediction.cpu():
                    correct[str(label.item())] += 1
                total[str(label.item())] += 1
    
    # Calculate total accuracy
    total_count = sum(total.values())
    correct_count = sum(correct.values())
    total_accuracy = 100 * float(correct_count) / total_count
    print(f'Total Accuracy: {total_accuracy:.1f} %')
    
    # Calculate old classes accuracy
    old_classes = [0, 1, 2, 3, 4]
    old_total = sum(total[str(i)] for i in old_classes)
    old_correct = sum(correct[str(i)] for i in old_classes)
    if old_total > 0:
        old_accuracy = 100 * float(old_correct) / old_total
        print(f'Old classes Accuracy: {old_accuracy:.1f} %')
    else:
        print(f'Old classes Accuracy: 00.0 %')
    
    # Calculate novel classes accuracy
    novel_classes = [5, 6, 7, 8, 9]
    novel_total = sum(total[str(i)] for i in novel_classes)
    novel_correct = sum(correct[str(i)] for i in novel_classes)
    if novel_total != 0:
        novel_accuracy = 100 * float(novel_correct) / novel_total
        print(f'Novel classes Accuracy: {novel_accuracy:.1f} %')
    else:
        print(f'Novel classes Accuracy: 00.0 %')
    
    # Accuracy for each class
    print('Accuracy for each class:')
    for idx, correct_count in correct.items():
        accuracy = 100 * float(correct_count) / total[idx]
        print(f'\t{class_name[int(idx)]:10s} : {accuracy:.1f} %')

# %%
# Fisher Information matrix
def compute_fisher_information(model, dataloader, criterion, device):
    model.eval()
    fisher_information = {n: torch.zeros(p.shape).to(device) for n, p in model.named_parameters()}
    for images, labels in dataloader:
        images, labels = images.to(device), labels.to(device)
        model.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        for n, p in model.named_parameters():
            if p.grad is not None:
                fisher_information[n] += p.grad.data.pow(2) * len(labels)
    fisher_information = {n: p / len(dataloader.dataset) for n, p in fisher_information.items()}
    return fisher_information

# EWC loss function
def ewc_loss(model, fisher_information, old_parameters, lambda_ewc):
    loss_ewc = 0
    for n, p in model.named_parameters():
        if n in fisher_information:
            loss_ewc += (fisher_information[n] * (p - old_parameters[n]).pow(2)).sum()
    return lambda_ewc * loss_ewc

# %%
# Distillation loss for LwF
def distillation_loss(y, teacher_scores, T, alpha):
    p = F.log_softmax(y / T, dim=1)
    q = F.softmax(teacher_scores / T, dim=1)
    l_kl = F.kl_div(p, q, reduction='batchmean') * (T * T * 2.0 * alpha)
    l_ce = F.cross_entropy(y, teacher_scores.argmax(dim=1)) * (1. - alpha)
    return l_kl + l_ce

# LwF Training
def train_lwf_ewc(student_model, teacher_model, train_loader, optimizer, criterion, fisher_information, old_parameters, lambda_ewc, alpha, T, device, epochs=20):
    student_model.train()
    teacher_model.eval()
    for epoch in range(epochs):
        total_loss = 0.0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = student_model(images)
            
            # Get soft targets from the teacher model
            with torch.no_grad():
                teacher_outputs = teacher_model(images)
            
            # Compute the classification loss, distillation loss, and EWC loss
            loss_ce = criterion(outputs, labels)
            loss_kd = distillation_loss(outputs, teacher_outputs, T, alpha)
            loss_ewc = ewc_loss(student_model, fisher_information, old_parameters, lambda_ewc)
            
            loss = loss_ce + loss_kd + 100*loss_ewc
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()
        print(f'Epoch {epoch+1}/{epochs}, Loss: {total_loss/len(train_loader)}')
        evaluate_model(student_model, test_loader, device)

# Compute Fisher Information after training the old model
lambda_ewc = 0.4  # Regularization strength for EWC
old_model.eval()
old_parameters = {n: p.clone().detach() for n, p in old_model.named_parameters()}
fisher_information = compute_fisher_information(old_model, train_loader, nn.CrossEntropyLoss(), device)

# Fine-tune the new model with combined LwF and EWC
alpha = 0.1  # LwF distillation parameter
T = 2.0     # Temperature for distillation
optimizer = torch.optim.SGD(new_model.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)
train_lwf_ewc(new_model, old_model, train_new_loader, optimizer, nn.CrossEntropyLoss(), fisher_information, old_parameters, lambda_ewc, alpha, T, device, epochs=50)
# Out:
# Epoch 1/50, Loss: 4.971718323474028
# Total Accuracy: 37.8 %
# Old classes Accuracy: 32.9 %
# Novel classes Accuracy: 42.7 %
# Accuracy for each class:
# 	airplane   : 43.5 %
# 	automobile : 15.6 %
# 	bird       : 1.9 %
# 	cat        : 63.9 %
# 	deer       : 39.4 %
# 	dog        : 30.5 %
# 	frog       : 41.9 %
# 	horse      : 32.1 %
# 	ship       : 27.7 %
# 	truck      : 81.2 %
# Epoch 2/50, Loss: 5.477641361100333
# Total Accuracy: 29.9 %
# Old classes Accuracy: 20.1 %
# Novel classes Accuracy: 39.6 %
# Accuracy for each class:
# 	airplane   : 7.4 %
# 	automobile : 12.3 %
# 	bird       : 0.0 %
# 	cat        : 56.8 %
# 	deer       : 24.0 %
# 	dog        : 9.7 %
# 	frog       : 52.6 %
# 	horse      : 12.4 %
# 	ship       : 86.8 %
# 	truck      : 36.6 %
# Epoch 3/50, Loss: 4.644251704216003
# Total Accuracy: 38.4 %
# Old classes Accuracy: 40.2 %
# Novel classes Accuracy: 36.7 %
# Accuracy for each class:
# 	airplane   : 55.9 %
# 	automobile : 48.6 %
# 	bird       : 4.4 %
# 	cat        : 68.0 %
# 	deer       : 24.2 %
# 	dog        : 28.0 %
# 	frog       : 57.9 %
# 	horse      : 38.4 %
# 	ship       : 25.6 %
# 	truck      : 33.4 %
# Epoch 4/50, Loss: 4.312517705012341
# Total Accuracy: 43.8 %
# Old classes Accuracy: 36.8 %
# Novel classes Accuracy: 50.8 %
# Accuracy for each class:
# 	airplane   : 21.8 %
# 	automobile : 72.0 %
# 	bird       : 14.4 %
# 	cat        : 50.4 %
# 	deer       : 25.3 %
# 	dog        : 25.1 %
# 	frog       : 70.3 %
# 	horse      : 65.9 %
# 	ship       : 65.3 %
# 	truck      : 27.2 %
# Epoch 5/50, Loss: 4.113364545666442
# Total Accuracy: 39.8 %
# Old classes Accuracy: 41.6 %
# Novel classes Accuracy: 38.1 %
# Accuracy for each class:
# 	airplane   : 34.0 %
# 	automobile : 58.2 %
# 	bird       : 10.7 %
# 	cat        : 68.2 %
# 	deer       : 36.7 %
# 	dog        : 10.1 %
# 	frog       : 79.5 %
# 	horse      : 7.7 %
# 	ship       : 67.3 %
# 	truck      : 25.8 %
# Epoch 6/50, Loss: 3.9509054008795292
# Total Accuracy: 40.9 %
# Old classes Accuracy: 40.3 %
# Novel classes Accuracy: 41.5 %
# Accuracy for each class:
# 	airplane   : 35.7 %
# 	automobile : 46.6 %
# 	bird       : 5.7 %
# 	cat        : 84.6 %
# 	deer       : 29.1 %
# 	dog        : 7.2 %
# 	frog       : 50.8 %
# 	horse      : 53.1 %
# 	ship       : 46.6 %
# 	truck      : 50.0 %
# Epoch 7/50, Loss: 3.8481978640264396
# Total Accuracy: 44.7 %
# Old classes Accuracy: 47.0 %
# Novel classes Accuracy: 42.5 %
# Accuracy for each class:
# 	airplane   : 40.8 %
# 	automobile : 75.6 %
# 	bird       : 8.5 %
# 	cat        : 69.4 %
# 	deer       : 40.5 %
# 	dog        : 21.1 %
# 	frog       : 65.1 %
# 	horse      : 35.7 %
# 	ship       : 62.2 %
# 	truck      : 28.5 %
# Epoch 8/50, Loss: 3.7808355640391915
# Total Accuracy: 45.4 %
# Old classes Accuracy: 47.7 %
# Novel classes Accuracy: 43.1 %
# Accuracy for each class:
# 	airplane   : 61.0 %
# 	automobile : 53.7 %
# 	bird       : 6.3 %
# 	cat        : 61.3 %
# 	deer       : 56.2 %
# 	dog        : 37.9 %
# 	frog       : 65.7 %
# 	horse      : 24.4 %
# 	ship       : 29.8 %
# 	truck      : 57.9 %
# Epoch 9/50, Loss: 3.715869517958894
# Total Accuracy: 49.3 %
# Old classes Accuracy: 46.9 %
# Novel classes Accuracy: 51.7 %
# Accuracy for each class:
# 	airplane   : 55.2 %
# 	automobile : 37.8 %
# 	bird       : 28.6 %
# 	cat        : 62.6 %
# 	deer       : 50.2 %
# 	dog        : 32.5 %
# 	frog       : 64.4 %
# 	horse      : 39.4 %
# 	ship       : 46.3 %
# 	truck      : 76.1 %
# Epoch 10/50, Loss: 3.6444858324771023
# Total Accuracy: 44.9 %
# Old classes Accuracy: 50.1 %
# Novel classes Accuracy: 39.8 %
# Accuracy for each class:
# 	airplane   : 62.6 %
# 	automobile : 73.3 %
# 	bird       : 13.2 %
# 	cat        : 72.7 %
# 	deer       : 28.8 %
# 	dog        : 19.7 %
# 	frog       : 71.3 %
# 	horse      : 30.7 %
# 	ship       : 43.1 %
# 	truck      : 34.0 %
# Epoch 11/50, Loss: 3.5924976553235735
# Total Accuracy: 49.9 %
# Old classes Accuracy: 52.8 %
# Novel classes Accuracy: 47.0 %
# Accuracy for each class:
# 	airplane   : 74.7 %
# 	automobile : 70.0 %
# 	bird       : 16.5 %
# 	cat        : 52.9 %
# 	deer       : 50.0 %
# 	dog        : 56.9 %
# 	frog       : 76.1 %
# 	horse      : 29.7 %
# 	ship       : 24.5 %
# 	truck      : 47.9 %
# Epoch 12/50, Loss: 3.5425401573278466
# Total Accuracy: 45.8 %
# Old classes Accuracy: 49.9 %
# Novel classes Accuracy: 41.6 %
# Accuracy for each class:
# 	airplane   : 55.6 %
# 	automobile : 52.1 %
# 	bird       : 7.6 %
# 	cat        : 68.2 %
# 	deer       : 66.2 %
# 	dog        : 28.9 %
# 	frog       : 60.5 %
# 	horse      : 21.4 %
# 	ship       : 42.4 %
# 	truck      : 54.6 %
# Epoch 13/50, Loss: 3.500782461798921
# Total Accuracy: 48.3 %
# Old classes Accuracy: 49.5 %
# Novel classes Accuracy: 47.1 %
# Accuracy for each class:
# 	airplane   : 65.6 %
# 	automobile : 53.7 %
# 	bird       : 27.5 %
# 	cat        : 72.8 %
# 	deer       : 27.7 %
# 	dog        : 24.8 %
# 	frog       : 55.5 %
# 	horse      : 61.7 %
# 	ship       : 46.9 %
# 	truck      : 46.4 %
# Epoch 14/50, Loss: 3.4479068359550165
# Total Accuracy: 48.7 %
# Old classes Accuracy: 48.7 %
# Novel classes Accuracy: 48.7 %
# Accuracy for each class:
# 	airplane   : 54.8 %
# 	automobile : 50.7 %
# 	bird       : 18.3 %
# 	cat        : 77.1 %
# 	deer       : 42.7 %
# 	dog        : 21.6 %
# 	frog       : 65.3 %
# 	horse      : 36.3 %
# 	ship       : 49.6 %
# 	truck      : 70.8 %
# Epoch 15/50, Loss: 3.423543090722999
# Total Accuracy: 48.1 %
# Old classes Accuracy: 57.2 %
# Novel classes Accuracy: 39.0 %
# Accuracy for each class:
# 	airplane   : 73.5 %
# 	automobile : 63.2 %
# 	bird       : 24.4 %
# 	cat        : 78.0 %
# 	deer       : 46.8 %
# 	dog        : 16.4 %
# 	frog       : 58.1 %
# 	horse      : 44.8 %
# 	ship       : 24.9 %
# 	truck      : 50.7 %
# Epoch 16/50, Loss: 3.3868544430148844
# Total Accuracy: 51.8 %
# Old classes Accuracy: 53.3 %
# Novel classes Accuracy: 50.3 %
# Accuracy for each class:
# 	airplane   : 63.2 %
# 	automobile : 67.8 %
# 	bird       : 27.5 %
# 	cat        : 52.8 %
# 	deer       : 55.3 %
# 	dog        : 59.3 %
# 	frog       : 63.4 %
# 	horse      : 33.0 %
# 	ship       : 48.0 %
# 	truck      : 47.7 %
# Epoch 17/50, Loss: 3.3466073870658875
# Total Accuracy: 48.9 %
# Old classes Accuracy: 49.0 %
# Novel classes Accuracy: 48.8 %
# Accuracy for each class:
# 	airplane   : 68.5 %
# 	automobile : 53.1 %
# 	bird       : 19.5 %
# 	cat        : 50.0 %
# 	deer       : 53.9 %
# 	dog        : 38.1 %
# 	frog       : 86.7 %
# 	horse      : 27.6 %
# 	ship       : 39.9 %
# 	truck      : 51.6 %
# Epoch 18/50, Loss: 3.323747614208533
# Total Accuracy: 48.7 %
# Old classes Accuracy: 56.4 %
# Novel classes Accuracy: 41.0 %
# Accuracy for each class:
# 	airplane   : 57.8 %
# 	automobile : 79.8 %
# 	bird       : 27.2 %
# 	cat        : 82.1 %
# 	deer       : 34.9 %
# 	dog        : 9.6 %
# 	frog       : 59.8 %
# 	horse      : 44.9 %
# 	ship       : 49.8 %
# 	truck      : 41.1 %
# Epoch 19/50, Loss: 3.280339075594532
# Total Accuracy: 49.6 %
# Old classes Accuracy: 56.0 %
# Novel classes Accuracy: 43.2 %
# Accuracy for each class:
# 	airplane   : 74.8 %
# 	automobile : 60.8 %
# 	bird       : 34.7 %
# 	cat        : 77.8 %
# 	deer       : 31.8 %
# 	dog        : 17.2 %
# 	frog       : 66.6 %
# 	horse      : 50.3 %
# 	ship       : 25.2 %
# 	truck      : 56.6 %
# Epoch 20/50, Loss: 3.2444838102982967
# Total Accuracy: 50.1 %
# Old classes Accuracy: 57.4 %
# Novel classes Accuracy: 42.8 %
# Accuracy for each class:
# 	airplane   : 65.8 %
# 	automobile : 81.3 %
# 	bird       : 37.6 %
# 	cat        : 62.8 %
# 	deer       : 39.7 %
# 	dog        : 30.7 %
# 	frog       : 72.7 %
# 	horse      : 38.9 %
# 	ship       : 39.7 %
# 	truck      : 31.8 %
# Epoch 21/50, Loss: 3.2165922619858565
# Total Accuracy: 49.1 %
# Old classes Accuracy: 56.8 %
# Novel classes Accuracy: 41.4 %
# Accuracy for each class:
# 	airplane   : 67.1 %
# 	automobile : 62.8 %
# 	bird       : 37.2 %
# 	cat        : 75.9 %
# 	deer       : 41.2 %
# 	dog        : 18.9 %
# 	frog       : 56.9 %
# 	horse      : 52.0 %
# 	ship       : 37.8 %
# 	truck      : 41.3 %
# Epoch 22/50, Loss: 3.1888840891876997
# Total Accuracy: 55.4 %
# Old classes Accuracy: 57.2 %
# Novel classes Accuracy: 53.6 %
# Accuracy for each class:
# 	airplane   : 54.3 %
# 	automobile : 75.9 %
# 	bird       : 39.8 %
# 	cat        : 59.4 %
# 	deer       : 56.8 %
# 	dog        : 32.4 %
# 	frog       : 75.1 %
# 	horse      : 47.6 %
# 	ship       : 59.7 %
# 	truck      : 53.3 %
# Epoch 23/50, Loss: 3.1802567073277066
# Total Accuracy: 54.5 %
# Old classes Accuracy: 56.6 %
# Novel classes Accuracy: 52.4 %
# Accuracy for each class:
# 	airplane   : 55.7 %
# 	automobile : 79.4 %
# 	bird       : 40.8 %
# 	cat        : 57.4 %
# 	deer       : 49.6 %
# 	dog        : 62.9 %
# 	frog       : 60.1 %
# 	horse      : 48.7 %
# 	ship       : 51.6 %
# 	truck      : 38.6 %
# Epoch 24/50, Loss: 3.1479128878943774
# Total Accuracy: 50.7 %
# Old classes Accuracy: 59.9 %
# Novel classes Accuracy: 41.5 %
# Accuracy for each class:
# 	airplane   : 67.4 %
# 	automobile : 69.7 %
# 	bird       : 25.4 %
# 	cat        : 74.3 %
# 	deer       : 62.9 %
# 	dog        : 34.4 %
# 	frog       : 52.7 %
# 	horse      : 27.7 %
# 	ship       : 30.4 %
# 	truck      : 62.2 %
# Epoch 25/50, Loss: 3.12139613774358
# Total Accuracy: 52.6 %
# Old classes Accuracy: 60.5 %
# Novel classes Accuracy: 44.7 %
# Accuracy for each class:
# 	airplane   : 75.9 %
# 	automobile : 79.3 %
# 	bird       : 16.7 %
# 	cat        : 58.8 %
# 	deer       : 71.7 %
# 	dog        : 47.0 %
# 	frog       : 62.3 %
# 	horse      : 39.4 %
# 	ship       : 31.2 %
# 	truck      : 43.4 %
# Epoch 26/50, Loss: 3.1068514609823423
# Total Accuracy: 52.1 %
# Old classes Accuracy: 61.5 %
# Novel classes Accuracy: 42.8 %
# Accuracy for each class:
# 	airplane   : 61.3 %
# 	automobile : 77.6 %
# 	bird       : 52.0 %
# 	cat        : 66.5 %
# 	deer       : 50.2 %
# 	dog        : 17.2 %
# 	frog       : 75.5 %
# 	horse      : 38.2 %
# 	ship       : 43.1 %
# 	truck      : 39.8 %
# Epoch 27/50, Loss: 3.0844659634998868
# Total Accuracy: 52.0 %
# Old classes Accuracy: 66.2 %
# Novel classes Accuracy: 37.8 %
# Accuracy for each class:
# 	airplane   : 77.5 %
# 	automobile : 89.9 %
# 	bird       : 37.8 %
# 	cat        : 77.2 %
# 	deer       : 48.4 %
# 	dog        : 31.0 %
# 	frog       : 67.5 %
# 	horse      : 42.7 %
# 	ship       : 22.4 %
# 	truck      : 25.5 %
# Epoch 28/50, Loss: 3.054274686745235
# Total Accuracy: 53.2 %
# Old classes Accuracy: 63.9 %
# Novel classes Accuracy: 42.5 %
# Accuracy for each class:
# 	airplane   : 73.2 %
# 	automobile : 86.5 %
# 	bird       : 37.6 %
# 	cat        : 77.4 %
# 	deer       : 44.6 %
# 	dog        : 27.3 %
# 	frog       : 68.6 %
# 	horse      : 46.4 %
# 	ship       : 33.5 %
# 	truck      : 36.5 %
# Epoch 29/50, Loss: 3.0545521123068675
# Total Accuracy: 56.7 %
# Old classes Accuracy: 60.9 %
# Novel classes Accuracy: 52.5 %
# Accuracy for each class:
# 	airplane   : 61.5 %
# 	automobile : 79.9 %
# 	bird       : 53.2 %
# 	cat        : 52.9 %
# 	deer       : 56.8 %
# 	dog        : 61.1 %
# 	frog       : 67.3 %
# 	horse      : 43.4 %
# 	ship       : 48.4 %
# 	truck      : 42.4 %
# Epoch 30/50, Loss: 3.007235231448193
# Total Accuracy: 53.2 %
# Old classes Accuracy: 65.8 %
# Novel classes Accuracy: 40.5 %
# Accuracy for each class:
# 	airplane   : 74.4 %
# 	automobile : 88.6 %
# 	bird       : 35.2 %
# 	cat        : 70.4 %
# 	deer       : 60.5 %
# 	dog        : 30.5 %
# 	frog       : 70.4 %
# 	horse      : 43.4 %
# 	ship       : 28.0 %
# 	truck      : 30.3 %
# Epoch 31/50, Loss: 2.9934597866875783
# Total Accuracy: 54.2 %
# Old classes Accuracy: 63.3 %
# Novel classes Accuracy: 45.1 %
# Accuracy for each class:
# 	airplane   : 60.6 %
# 	automobile : 86.0 %
# 	bird       : 46.8 %
# 	cat        : 78.8 %
# 	deer       : 44.1 %
# 	dog        : 29.2 %
# 	frog       : 47.6 %
# 	horse      : 66.9 %
# 	ship       : 46.4 %
# 	truck      : 35.5 %
# Epoch 32/50, Loss: 2.9710512441031787
# Total Accuracy: 56.9 %
# Old classes Accuracy: 65.5 %
# Novel classes Accuracy: 48.3 %
# Accuracy for each class:
# 	airplane   : 80.0 %
# 	automobile : 82.1 %
# 	bird       : 48.1 %
# 	cat        : 59.8 %
# 	deer       : 57.4 %
# 	dog        : 52.9 %
# 	frog       : 75.2 %
# 	horse      : 42.4 %
# 	ship       : 32.5 %
# 	truck      : 38.4 %
# Epoch 33/50, Loss: 2.9456499705509263
# Total Accuracy: 55.8 %
# Old classes Accuracy: 68.6 %
# Novel classes Accuracy: 43.0 %
# Accuracy for each class:
# 	airplane   : 75.3 %
# 	automobile : 92.9 %
# 	bird       : 36.0 %
# 	cat        : 65.7 %
# 	deer       : 73.3 %
# 	dog        : 34.0 %
# 	frog       : 69.2 %
# 	horse      : 43.4 %
# 	ship       : 37.7 %
# 	truck      : 30.9 %
# Epoch 34/50, Loss: 2.9250321193617217
# Total Accuracy: 53.9 %
# Old classes Accuracy: 66.6 %
# Novel classes Accuracy: 41.2 %
# Accuracy for each class:
# 	airplane   : 75.8 %
# 	automobile : 81.1 %
# 	bird       : 35.9 %
# 	cat        : 74.0 %
# 	deer       : 66.3 %
# 	dog        : 25.6 %
# 	frog       : 70.1 %
# 	horse      : 38.1 %
# 	ship       : 25.8 %
# 	truck      : 46.5 %
# Epoch 35/50, Loss: 2.930770681828869
# Total Accuracy: 54.4 %
# Old classes Accuracy: 67.1 %
# Novel classes Accuracy: 41.6 %
# Accuracy for each class:
# 	airplane   : 85.0 %
# 	automobile : 71.9 %
# 	bird       : 41.5 %
# 	cat        : 77.2 %
# 	deer       : 60.1 %
# 	dog        : 17.8 %
# 	frog       : 62.1 %
# 	horse      : 51.3 %
# 	ship       : 28.1 %
# 	truck      : 48.6 %
# Epoch 36/50, Loss: 2.905464004497139
# Total Accuracy: 53.9 %
# Old classes Accuracy: 65.0 %
# Novel classes Accuracy: 42.8 %
# Accuracy for each class:
# 	airplane   : 83.7 %
# 	automobile : 64.6 %
# 	bird       : 49.4 %
# 	cat        : 83.0 %
# 	deer       : 44.2 %
# 	dog        : 17.5 %
# 	frog       : 44.2 %
# 	horse      : 57.4 %
# 	ship       : 32.6 %
# 	truck      : 62.2 %
# Epoch 37/50, Loss: 2.8910678795405795
# Total Accuracy: 57.0 %
# Old classes Accuracy: 70.8 %
# Novel classes Accuracy: 43.2 %
# Accuracy for each class:
# 	airplane   : 74.5 %
# 	automobile : 91.2 %
# 	bird       : 45.8 %
# 	cat        : 76.1 %
# 	deer       : 66.6 %
# 	dog        : 29.0 %
# 	frog       : 63.6 %
# 	horse      : 46.0 %
# 	ship       : 42.5 %
# 	truck      : 34.7 %
# Epoch 38/50, Loss: 2.8666057951596318
# Total Accuracy: 60.0 %
# Old classes Accuracy: 64.4 %
# Novel classes Accuracy: 55.5 %
# Accuracy for each class:
# 	airplane   : 56.1 %
# 	automobile : 85.3 %
# 	bird       : 54.8 %
# 	cat        : 67.6 %
# 	deer       : 58.2 %
# 	dog        : 39.1 %
# 	frog       : 66.3 %
# 	horse      : 69.8 %
# 	ship       : 60.1 %
# 	truck      : 42.3 %
# Epoch 39/50, Loss: 2.8544221848857645
# Total Accuracy: 54.0 %
# Old classes Accuracy: 66.6 %
# Novel classes Accuracy: 41.4 %
# Accuracy for each class:
# 	airplane   : 85.3 %
# 	automobile : 77.8 %
# 	bird       : 45.0 %
# 	cat        : 79.2 %
# 	deer       : 45.9 %
# 	dog        : 17.8 %
# 	frog       : 66.7 %
# 	horse      : 54.8 %
# 	ship       : 29.9 %
# 	truck      : 38.0 %
# Epoch 40/50, Loss: 2.84076005950266
# Total Accuracy: 58.6 %
# Old classes Accuracy: 66.3 %
# Novel classes Accuracy: 50.9 %
# Accuracy for each class:
# 	airplane   : 71.2 %
# 	automobile : 96.0 %
# 	bird       : 50.9 %
# 	cat        : 60.8 %
# 	deer       : 52.7 %
# 	dog        : 45.7 %
# 	frog       : 71.3 %
# 	horse      : 59.9 %
# 	ship       : 51.6 %
# 	truck      : 25.9 %
# Epoch 41/50, Loss: 2.8294328244364992
# Total Accuracy: 55.1 %
# Old classes Accuracy: 69.3 %
# Novel classes Accuracy: 40.9 %
# Accuracy for each class:
# 	airplane   : 73.8 %
# 	automobile : 90.3 %
# 	bird       : 49.0 %
# 	cat        : 83.0 %
# 	deer       : 50.3 %
# 	dog        : 19.1 %
# 	frog       : 61.0 %
# 	horse      : 54.9 %
# 	ship       : 35.4 %
# 	truck      : 34.0 %
# Epoch 42/50, Loss: 2.8265728597738304
# Total Accuracy: 59.2 %
# Old classes Accuracy: 72.3 %
# Novel classes Accuracy: 46.1 %
# Accuracy for each class:
# 	airplane   : 77.1 %
# 	automobile : 93.3 %
# 	bird       : 64.3 %
# 	cat        : 57.3 %
# 	deer       : 69.4 %
# 	dog        : 50.9 %
# 	frog       : 69.8 %
# 	horse      : 48.8 %
# 	ship       : 36.3 %
# 	truck      : 24.8 %
# Epoch 43/50, Loss: 2.8042720617080223
# Total Accuracy: 58.0 %
# Old classes Accuracy: 69.9 %
# Novel classes Accuracy: 46.0 %
# Accuracy for each class:
# 	airplane   : 54.4 %
# 	automobile : 94.4 %
# 	bird       : 55.0 %
# 	cat        : 70.4 %
# 	deer       : 75.5 %
# 	dog        : 44.4 %
# 	frog       : 55.3 %
# 	horse      : 32.8 %
# 	ship       : 71.9 %
# 	truck      : 25.8 %
# Epoch 44/50, Loss: 2.7798646615476024
# Total Accuracy: 57.7 %
# Old classes Accuracy: 70.0 %
# Novel classes Accuracy: 45.4 %
# Accuracy for each class:
# 	airplane   : 88.4 %
# 	automobile : 84.3 %
# 	bird       : 41.2 %
# 	cat        : 72.8 %
# 	deer       : 63.2 %
# 	dog        : 30.2 %
# 	frog       : 69.0 %
# 	horse      : 53.6 %
# 	ship       : 38.3 %
# 	truck      : 36.1 %
# Epoch 45/50, Loss: 2.764769442227422
# Total Accuracy: 57.7 %
# Old classes Accuracy: 71.6 %
# Novel classes Accuracy: 43.8 %
# Accuracy for each class:
# 	airplane   : 74.4 %
# 	automobile : 90.4 %
# 	bird       : 59.0 %
# 	cat        : 73.4 %
# 	deer       : 60.6 %
# 	dog        : 26.6 %
# 	frog       : 69.0 %
# 	horse      : 42.9 %
# 	ship       : 48.0 %
# 	truck      : 32.5 %
# Epoch 46/50, Loss: 2.762396738237264
# Total Accuracy: 56.9 %
# Old classes Accuracy: 68.9 %
# Novel classes Accuracy: 44.9 %
# Accuracy for each class:
# 	airplane   : 73.2 %
# 	automobile : 88.1 %
# 	bird       : 58.2 %
# 	cat        : 77.1 %
# 	deer       : 47.7 %
# 	dog        : 34.1 %
# 	frog       : 64.2 %
# 	horse      : 51.0 %
# 	ship       : 38.4 %
# 	truck      : 36.9 %
# Epoch 47/50, Loss: 2.740143302752047
# Total Accuracy: 56.7 %
# Old classes Accuracy: 69.7 %
# Novel classes Accuracy: 43.6 %
# Accuracy for each class:
# 	airplane   : 85.2 %
# 	automobile : 76.5 %
# 	bird       : 54.3 %
# 	cat        : 68.2 %
# 	deer       : 64.4 %
# 	dog        : 21.8 %
# 	frog       : 69.0 %
# 	horse      : 53.9 %
# 	ship       : 26.0 %
# 	truck      : 47.5 %
# Epoch 48/50, Loss: 2.7469442316464017
# Total Accuracy: 56.5 %
# Old classes Accuracy: 74.0 %
# Novel classes Accuracy: 39.0 %
# Accuracy for each class:
# 	airplane   : 76.2 %
# 	automobile : 89.9 %
# 	bird       : 60.4 %
# 	cat        : 80.1 %
# 	deer       : 63.5 %
# 	dog        : 25.6 %
# 	frog       : 57.6 %
# 	horse      : 44.9 %
# 	ship       : 35.0 %
# 	truck      : 31.9 %
# Epoch 49/50, Loss: 2.724276458730503
# Total Accuracy: 58.5 %
# Old classes Accuracy: 72.3 %
# Novel classes Accuracy: 44.7 %
# Accuracy for each class:
# 	airplane   : 74.1 %
# 	automobile : 87.6 %
# 	bird       : 57.5 %
# 	cat        : 70.5 %
# 	deer       : 71.7 %
# 	dog        : 36.3 %
# 	frog       : 52.6 %
# 	horse      : 60.5 %
# 	ship       : 41.0 %
# 	truck      : 33.1 %
# Epoch 50/50, Loss: 2.7069959968936685
# Total Accuracy: 56.0 %
# Old classes Accuracy: 70.2 %
# Novel classes Accuracy: 41.9 %
# Accuracy for each class:
# 	airplane   : 78.7 %
# 	automobile : 81.5 %
# 	bird       : 45.5 %
# 	cat        : 79.3 %
# 	deer       : 65.8 %
# 	dog        : 28.5 %
# 	frog       : 58.8 %
# 	horse      : 47.3 %
# 	ship       : 34.5 %
# 	truck      : 40.6 %

# %%
torch.save(new_model.state_dict(), 'new_model.pth')
